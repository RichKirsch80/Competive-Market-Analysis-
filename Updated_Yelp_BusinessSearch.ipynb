# %%
import requests
import json
import pandas as pd
from pprint import pprint
from config import api_key

# %%
api_key
# Out:
# 'ZbL8RBc6OIart11c2yr3RzFDf6_OX4lc4MKMulZ1Sj6Xe39v4PNLslWf1ysrSCE5gRQbq3Qr_Z6bVNX1CtfqkShNfBO749RtythyH77bxk53f1brpSqTgYc6OKsIYXYx'

# %%
base_url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'bearer %s' % api_key}
criteria = {
            'latitude':42.22281199117525,
            'longitude':-87.97140264669633,
            'radius': 8100,
            'term': 'food'
}

# %%
restaurant_response = requests.get(base_url,criteria,headers=headers).json()

pprint(restaurant_response)
# Out:
# {'businesses': [{'alias': 'bb-q-chicken-vernon-hills-vernon-hills',
#                  'categories': [{'alias': 'chickenshop',
#                                  'title': 'Chicken Shop'},
#                                 {'alias': 'korean', 'title': 'Korean'}],
#                  'coordinates': {'latitude': 42.24006, 'longitude': -87.9411},
#                  'display_phone': '(224) 424-4915',
#                  'distance': 3146.8725097479232,
#                  'id': 'y6Y5M0sjwfPlDOOs4A_mcQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eJxvSevkvfonC6YtMTbKDw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '701 N Milwaukee Ave',
#                               'address2': 'Unit 348',
#                               'address3': '',
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['701 N Milwaukee Ave',
#                                                   'Unit 348',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'bb.q Chicken - Vernon Hills',
#                  'phone': '+12244244915',
#                  'rating': 4.5,
#                  'review_count': 20,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/bb-q-chicken-vernon-hills-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'poke-bros-lincolnshire-2',
#                  'categories': [{'alias': 'poke', 'title': 'Poke'},
#                                 {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#                  'coordinates': {'latitude': 42.18213661620124,
#                                  'longitude': -87.92907409824396},
#                  'display_phone': '(847) 383-5255',
#                  'distance': 5710.783561518129,
#                  'id': 'zZZjMOQLYvvsm87geCHWyw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VQ2GQBfCIV9sluspQAPafA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '950B Milwaukee Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Lincolnshire',
#                               'country': 'US',
#                               'display_address': ['950B Milwaukee Ave',
#                                                   'Lincolnshire, IL 60069'],
#                               'state': 'IL',
#                               'zip_code': '60069'},
#                  'name': 'Poke Bros',
#                  'phone': '+18473835255',
#                  'rating': 5.0,
#                  'review_count': 4,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/poke-bros-lincolnshire-2?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'bonta-lincolnshire-4',
#                  'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#                                 {'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 42.1991299,
#                                  'longitude': -87.93302},
#                  'display_phone': '(847) 383-6233',
#                  'distance': 4115.967245813689,
#                  'id': 'pDr9PC7jD7LBnLgJxD_4wQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dFcKCQVsgFuH5PyKPUnupw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '430 Milwaukee Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Lincolnshire',
#                               'country': 'US',
#                               'display_address': ['430 Milwaukee Ave',
#                                                   'Lincolnshire, IL 60069'],
#                               'state': 'IL',
#                               'zip_code': '60069'},
#                  'name': 'Bonta',
#                  'phone': '+18473836233',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 499,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/bonta-lincolnshire-4?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'ramen-house-shinchan-vernon-hills',
#                  'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#                  'coordinates': {'latitude': 42.238635,
#                                  'longitude': -87.941136},
#                  'display_phone': '(847) 984-2105',
#                  'distance': 3050.48918073077,
#                  'id': 'VvYtvrRnKJ8UUvJbRHYV5Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ipp1JydtjnTvsbilXGK_cw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '701 N Milwaukee Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['701 N Milwaukee Ave',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'Ramen House Shinchan',
#                  'phone': '+18479842105',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 71,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/ramen-house-shinchan-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'lazy-dog-restaurant-and-bar-vernon-hills',
#                  'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'comfortfood',
#                                  'title': 'Comfort Food'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 42.24452, 'longitude': -87.94513},
#                  'display_phone': '(847) 780-7977',
#                  'distance': 3262.42864338753,
#                  'id': 'uqbIttno2vux1wW1mpyvgw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DbgBTOfrNkld3rja5ljuZw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1115 N Milwaukee Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['1115 N Milwaukee Ave',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'Lazy Dog Restaurant & Bar',
#                  'phone': '+18477807977',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 728,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/lazy-dog-restaurant-and-bar-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'teriyaki-madness-vernon-hills',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 42.24198687746965,
#                                  'longitude': -87.94415433395226},
#                  'display_phone': '(224) 513-5071',
#                  'distance': 3094.9728066606235,
#                  'id': '1kdRC-PWxUL-WEXN8ILEMQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9-rJvy0QYpnnxO98b9KcMg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '875 N Milwaukee Ave',
#                               'address2': 'Unit 700',
#                               'address3': '',
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['875 N Milwaukee Ave',
#                                                   'Unit 700',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'Teriyaki Madness',
#                  'phone': '+12245135071',
#                  'rating': 3.5,
#                  'review_count': 38,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/teriyaki-madness-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'fat-rosies-taco-and-tequila-bar-lincolnshire',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 42.182412,
#                                  'longitude': -87.928872},
#                  'display_phone': '(224) 377-2395',
#                  'distance': 5698.974428728879,
#                  'id': 'Tarq5H7WDpH3XPua7aKTRw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4qVl9p5k-L5dSxOJlLJCNQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '940 Milwaukee Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Lincolnshire',
#                               'country': 'US',
#                               'display_address': ['940 Milwaukee Ave',
#                                                   'Lincolnshire, IL 60069'],
#                               'state': 'IL',
#                               'zip_code': '60069'},
#                  'name': "Fat Rosie's Taco & Tequila Bar",
#                  'phone': '+12243772395',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 125,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/fat-rosies-taco-and-tequila-bar-lincolnshire?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'vans-sushi-cafe-vernon-hills',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 42.201184,
#                                  'longitude': -87.933535},
#                  'display_phone': '(847) 383-6244',
#                  'distance': 3943.4285058945597,
#                  'id': '9m_qTYOTx1BAMwggpptnrg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UNNy67bMBzTxqhQhNefY5g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1356 S Milwaukee Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['1356 S Milwaukee Ave',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': "Van's Sushi Cafe",
#                  'phone': '+18473836244',
#                  'rating': 4.5,
#                  'review_count': 87,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/vans-sushi-cafe-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'zocalo-mexican-bar-and-grill-vernon-hills',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 42.2300346,
#                                  'longitude': -87.9769051},
#                  'display_phone': '(224) 513-5477',
#                  'distance': 898.6126674192965,
#                  'id': 'BMyK4sreXs6ER5k1WAosBQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MIPJ33P0P4qejpNJlrTf7A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '203 Butterfield Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['203 Butterfield Rd',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'Zocalo Mexican Bar and Grill',
#                  'phone': '+12245135477',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 213,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/zocalo-mexican-bar-and-grill-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'bella-famiglia-vernon-hills',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 42.222199,
#                                  'longitude': -87.970158},
#                  'display_phone': '(847) 816-6161',
#                  'distance': 122.02202635165159,
#                  'id': 'nIYtcxg2eFDjeeupn6Tv9w',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MUvpt03WJJeuJVlqEdlJ8A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '277 Evergreen Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['277 Evergreen Dr',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'Bella Famiglia',
#                  'phone': '+18478166161',
#                  'rating': 4.0,
#                  'review_count': 12,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/bella-famiglia-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'invicto-vernon-hills-4',
#                  'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#                  'coordinates': {'latitude': 42.2420949757054,
#                                  'longitude': -87.9443318891231},
#                  'display_phone': '(224) 504-2156',
#                  'distance': 3092.712986356632,
#                  'id': '3I-VeEsjwb0zWBzownTUOQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lEMZ1qAJXAsjT_9-rFmP8g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '887 N Milwaukee Ave',
#                               'address2': 'Ste 300',
#                               'address3': None,
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['887 N Milwaukee Ave',
#                                                   'Ste 300',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'Invicto',
#                  'phone': '+12245042156',
#                  'rating': 4.0,
#                  'review_count': 152,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/invicto-vernon-hills-4?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'kumas-sushi-bowl-vernon-hills',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 42.2399892351077,
#                                  'longitude': -87.9416033261764},
#                  'display_phone': '(224) 206-7953',
#                  'distance': 3109.2816140523028,
#                  'id': '1a9ssCh8okKaMpySZ4mIvg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IOeQjijr41dw5gmhkd6qjg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '701 N Milwaukee Ave',
#                               'address2': 'Ste 316',
#                               'address3': '',
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['701 N Milwaukee Ave',
#                                                   'Ste 316',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': "Kuma's sushi bowl",
#                  'phone': '+12242067953',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 182,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/kumas-sushi-bowl-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'city-works-vernon-hills-vernon-hills',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'sportsbars',
#                                  'title': 'Sports Bars'}],
#                  'coordinates': {'latitude': 42.243903,
#                                  'longitude': -87.944425},
#                  'display_phone': '(847) 984-3571',
#                  'distance': 3230.0429469841347,
#                  'id': 'hjcAQS4VzSA12uHbP_6C-w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-gsiUbfajSJTkcX7ecm3nw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '929 N Milwaukee Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['929 N Milwaukee Ave',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'City Works - Vernon Hills',
#                  'phone': '+18479843571',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 100,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/city-works-vernon-hills-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'blufish-sushi-robata-vernon-hills',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 42.238507, 'longitude': -87.94773},
#                  'display_phone': '(847) 549-3620',
#                  'distance': 2616.2092897353346,
#                  'id': 'W4jrdps3efXU4JvHxPdBIg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ltHOLhNikvxL1cStXiCtog/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '700 N Milwaukee Ave',
#                               'address2': 'Ste 128',
#                               'address3': '',
#                               'city': 'Vernon Hills',
#                               'country': 'US',
#                               'display_address': ['700 N Milwaukee Ave',
#                                                   'Ste 128',
#                                                   'Vernon Hills, IL 60061'],
#                               'state': 'IL',
#                               'zip_code': '60061'},
#                  'name': 'Blufish Sushi Robata',
#                  'phone': '+18475493620',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 376,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/blufish-sushi-robata-vernon-hills?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'lolo-s-bowls-libertyville',
#                  'categories': [{'alias': 'acaibowls', 'title': 'Acai Bowls'},
#                                 {'alias': 'juicebars',
#                                  'title': 'Juice Bars & Smoothies'}],
#                  'coordinates': {'latitude': 42.274321,
#                                  'longitude': -87.9499666351},
#                  'display_phone': '(224) 513-5358',
#                  'distance': 5993.143418998639,
#                  'id': 'wNV5NHjrlHNF0bOb_-rl8A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6WyqrzhPHaE98A7bL2RZdA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '854 S Milwaukee Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Libertyville',
#                               'country': 'US',
#                               'display_address': ['854 S Milwaukee Ave',
#                                                   'Libertyville, IL 60048'],
#                               'state': 'IL',
#                               'zip_code': '60048'},
#                  'name': 'Lolo’s Bowls',
#                  'phone': '+12245135358',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 15,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/lolo-s-bowls-libertyville?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'hwang-dae-gham-mundelein',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'korean', 'title': 'Korean'}],
#                  'coordinates': {'latitude': 42.2401349,
#                                  'longitude': -87.99665},
#                  'display_phone': '(847) 949-9900',
#                  'distance': 3030.581152348884,
#                  'id': '6Mj9E3TTRWIiDkwyDSYW2A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FuOGAeOTC3-FUgg6StHSOQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '358 Townline Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mundelein',
#                               'country': 'US',
#                               'display_address': ['358 Townline Rd',
#                                                   'Mundelein, IL 60060'],
#                               'state': 'IL',
#                               'zip_code': '60060'},
#                  'name': 'Hwang Dae Gham',
#                  'phone': '+18479499900',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 100,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/hwang-dae-gham-mundelein?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'dangelas-dumplings-libertyville',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#                  'coordinates': {'latitude': 42.2838100710772,
#                                  'longitude': -87.9538044796491},
#                  'display_phone': '(847) 549-3248',
#                  'distance': 6935.5944630765325,
#                  'id': 'wt8k03YqhC8lOmcQlUFbTg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1JnXLcubPybnQZMoO1-31Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '133 N Milwaukee Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Libertyville',
#                               'country': 'US',
#                               'display_address': ['133 N Milwaukee Ave',
#                                                   'Libertyville, IL 60048'],
#                               'state': 'IL',
#                               'zip_code': '60048'},
#                  'name': "Dangela's Dumplings",
#                  'phone': '+18475493248',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 105,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/dangelas-dumplings-libertyville?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'the-port-of-peri-peri-buffalo-grove',
#                  'categories': [{'alias': 'portuguese', 'title': 'Portuguese'}],
#                  'coordinates': {'latitude': 42.181499,
#                                  'longitude': -87.9647403},
#                  'display_phone': '(847) 383-5689',
#                  'distance': 4626.453126739405,
#                  'id': 'xhV4LS-RhH0d_uUegkQVEg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P_BRbiu_2AWMCrGyNQpTlQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1663 N Buffalo Grove Rd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Buffalo Grove',
#                               'country': 'US',
#                               'display_address': ['1663 N Buffalo Grove Rd',
#                                                   'Buffalo Grove, IL 60089'],
#                               'state': 'IL',
#                               'zip_code': '60089'},
#                  'name': 'The Port of Peri Peri',
#                  'phone': '+18473835689',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 112,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/the-port-of-peri-peri-buffalo-grove?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'oaken-bistro-bar-lake-forest-2',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 42.244219941039475,
#                                  'longitude': -87.89831479413108},
#                  'display_phone': '(847) 582-6410',
#                  'distance': 6471.062671255154,
#                  'id': 'J4OvE06JrW4ae9c7oht08w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Cn1R9AsSBgoNBnPLX57jXw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '200 N Field Dr',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Lake Forest',
#                               'country': 'US',
#                               'display_address': ['200 N Field Dr',
#                                                   'Lake Forest, IL 60045'],
#                               'state': 'IL',
#                               'zip_code': '60045'},
#                  'name': 'Oaken Bistro + Bar',
#                  'phone': '+18475826410',
#                  'rating': 4.0,
#                  'review_count': 15,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/oaken-bistro-bar-lake-forest-2?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'},
#                 {'alias': 'viet-taste-libertyville-2',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#                  'coordinates': {'latitude': 42.264521,
#                                  'longitude': -87.950913},
#                  'display_phone': '(847) 984-2776',
#                  'distance': 4934.994786992483,
#                  'id': 'OvHoeiR3_cIoF6brRwjurQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_2QRrlBDm1ov9dKIj2XdvA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1183 S Milwaukee Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Libertyville',
#                               'country': 'US',
#                               'display_address': ['1183 S Milwaukee Ave',
#                                                   'Libertyville, IL 60048'],
#                               'state': 'IL',
#                               'zip_code': '60048'},
#                  'name': 'Viet Taste',
#                  'phone': '+18479842776',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 53,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/viet-taste-libertyville-2?adjust_creative=P7yawaMqBCB4Q671o7aJEQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P7yawaMqBCB4Q671o7aJEQ'}],
#  'region': {'center': {'latitude': 42.22281199117525,
#                        'longitude': -87.97140264669633}},
#  'total': 598}

# %%
base_url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'bearer %s' % api_key}
criteria = {
            'latitude':42.22281199117525,
            'longitude':-87.97140264669633,
            'radius': 16000,
            'term': 'food'
}

restaurant_response = requests.get(base_url,criteria,headers=headers).json()

# %%
restaurant_response['total']
# Out:
# 2300

# %%
bus_ids = list()
indices = list()
errors = list()


for i in range(0,2300,50):
    criteria = {
        'offset':i,
        'limit':50,
        'latitude':42.22281199117525,
        'longitude':-87.97140264669633,
        'radius': 8100,
        'term': 'food'
    }
    restaurant_response = requests.get(base_url,criteria,headers=headers).json()
    try:
        for idx,bus_dict in enumerate(restaurant_response['businesses']):
            try:
                indices.append(idx)
                bus_ids.append(bus_dict['id'])
            except:
                errors.append(bus_id)
    except:
        errors.append(f'offset {i}')
business_df = pd.DataFrame({
    'Business IDs':bus_ids,
})
business_df
# Out:
#                Business IDs
# 0    y6Y5M0sjwfPlDOOs4A_mcQ
# 1    zZZjMOQLYvvsm87geCHWyw
# 2    pDr9PC7jD7LBnLgJxD_4wQ
# 3    VvYtvrRnKJ8UUvJbRHYV5Q
# 4    uqbIttno2vux1wW1mpyvgw
# ..                      ...
# 593  52w_JtjxiqK6nSrtnNPZGA
# 594  qQPnO_9rnRQs5K3JsYTZ9Q
# 595  YlUXqi1aZjMM0-x-vqfdKQ
# 596  8xLgvQZwOfR7HX2AXi5CnQ
# 597  XWjnysDFCi9Dxc17mnIDQw
#
# [598 rows x 1 columns]

# %%
business_df.to_csv('restaurantIDs.csv', index = False)

# %%
len(business_df)
# Out:
# 598

# %%
len(errors)
# Out:
# 26

# %%
print(errors)
# Out:
# ['offset 1000', 'offset 1050', 'offset 1100', 'offset 1150', 'offset 1200', 'offset 1250', 'offset 1300', 'offset 1350', 'offset 1400', 'offset 1450', 'offset 1500', 'offset 1550', 'offset 1600', 'offset 1650', 'offset 1700', 'offset 1750', 'offset 1800', 'offset 1850', 'offset 1900', 'offset 1950', 'offset 2000', 'offset 2050', 'offset 2100', 'offset 2150', 'offset 2200', 'offset 2250']
